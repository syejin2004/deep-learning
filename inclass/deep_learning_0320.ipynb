# %% [markdown]
# <a href="https://colab.research.google.com/github/syejin2004/deep-learning/blob/main/inclass/deep_learning_0320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **10장**

# %%
import sys

assert sys.version_info >= (3,7)

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

import sys
# 코랩의 경우 나눔 폰트를 설치합니다.
if 'google.colab' in sys.modules:
    # !sudo apt-get -qq -y install fonts-nanum
    import matplotlib.font_manager as fm
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])
    for fpath in font_files:
        fm.fontManager.addfont(fpath)

# 나눔 폰트를 사용합니다.
import matplotlib

matplotlib.rc('font', family='NanumBarunGothic')
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "ann"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ### 퍼셉트론

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris(as_frame=True)
X = iris.data[["petal length (cm)", "petal width (cm)"]].values
y = (iris.target == 0)

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

X_new = [[2, 0.5], [3, 1], [3, 0.5], [2, 0.3]]
y_pred = per_clf.predict(X_new)

y_pred
# Out:
# array([ True, False, False,  True])

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

a = -per_clf.coef_[0, 0] / per_clf.coef_[0, 1]
b = -per_clf.intercept_ / per_clf.coef_[0, 1]
axes = [0, 5, 0, 2]
x0, x1 = np.meshgrid(
    np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
    np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
)
X_new = np.c_[x0.ravel(), x1.ravel()]
y_predict = per_clf.predict(X_new)
zz = y_predict.reshape(x0.shape)
custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

plt.figure(figsize=(7, 3))
plt.plot(X[y == 0, 0], X[y == 0, 1], "bs", label="Iris setosa 아님")
plt.plot(X[y == 1, 0], X[y == 1, 1], "yo", label="Iris setosa")
plt.plot([axes[0], axes[1]], [a * axes[0] + b, a * axes[1] + b], "k-",
         linewidth=3)
plt.contourf(x0, x1, zz, cmap=custom_cmap)
plt.xlabel("꽃잎 길이")
plt.ylabel("꽃잎 너비")
plt.legend(loc="lower right")
plt.axis(axes)
plt.show()

# %% [markdown]
# ## 회귀 MLP

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

mlp_reg = MLPRegressor(hidden_layer_sizes=[100, 100, 100], random_state=42)  #은닉층이 무조건 많다고 좋은게 아니다.
pipeline = make_pipeline(StandardScaler(), mlp_reg)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_valid)
rmse = mean_squared_error(y_valid, y_pred, squared=False)   # 정확도 환산 (1에 가까워지면 된다.)

rmse
# Out:
# 0.9699531549725992

# %% [markdown]
# ## 분류 MLP

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

iris = load_iris()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    iris.data, iris.target, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, test_size=0.1, random_state=42)

mlp_clf = MLPClassifier(hidden_layer_sizes=[5], max_iter=10_000,
                        random_state=42)
pipeline = make_pipeline(StandardScaler(), mlp_clf)
pipeline.fit(X_train, y_train)
accuracy = pipeline.score(X_valid, y_valid)
accuracy
# Out:
# 1.0

# %%
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.subplots_adjust(wspace=0.2, hspace=0.5)

save_fig("fashion_mnist_plot")
plt.show()

# %% [markdown]
# ## 시퀀셜 API를 사용하여 모델 만들기

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=(28, 28)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation="relu"))
model.add(tf.keras.layers.Dense(100, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 300)               235500
#
#  dense_4 (Dense)             (None, 100)               30100
#
#  dense_5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266610 (1.02 MB)
# Trainable params: 266610 (1.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 컴파일

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %% [markdown]
# ### 모델 훈련 및 평가

# %%
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.7262 - accuracy: 0.7619 - val_loss: 0.5146 - val_accuracy: 0.8234
# Epoch 2/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.4934 - accuracy: 0.8294 - val_loss: 0.4692 - val_accuracy: 0.8340
# Epoch 3/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4459 - accuracy: 0.8443 - val_loss: 0.4314 - val_accuracy: 0.8512
# Epoch 4/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.4202 - accuracy: 0.8534 - val_loss: 0.4010 - val_accuracy: 0.8608
# Epoch 5/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3983 - accuracy: 0.8613 - val_loss: 0.3940 - val_accuracy: 0.8578
# Epoch 6/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3813 - accuracy: 0.8649 - val_loss: 0.3962 - val_accuracy: 0.8606
# Epoch 7/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3686 - accuracy: 0.8696 - val_loss: 0.3747 - val_accuracy: 0.8682
# Epoch 8/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3566 - accuracy: 0.8742 - val_loss: 0.3704 - val_accuracy: 0.8674
# Epoch 9/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3456 - accuracy: 0.8771 - val_loss: 0.3517 - val_accuracy: 0.8724
# Epoch 10/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3354 - accuracy: 0.8800 - val_loss: 0.3511 - val_accuracy: 0.8734
# Epoch 11/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3270 - accuracy: 0.8825 - val_loss: 0.3689 - val_accuracy: 0.8652
# Epoch 12/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3191 - accuracy: 0.8852 - val_loss: 0.3465 - val_accuracy: 0.8724
# Epoch 13/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3116 - accuracy: 0.8894 - val_loss: 0.3288 - val_accuracy: 0.8816
# Epoch 14/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3047 - accuracy: 0.8900 - val_loss: 0.3374 - val_accuracy: 0.8782
# Epoch 15/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2985 - accuracy: 0.8936 - val_loss: 0.3399 - val_accuracy: 0.8792
# Epoch 16/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2919 - accuracy: 0.8950 - val_loss: 0.3291 - val_accuracy: 0.8796
# Epoch 17/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2870 - accuracy: 0.8963 - val_loss: 0.3347 - val_accuracy: 0.8770
# Epoch 18/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2807 - accuracy: 0.8992 - val_loss: 0.3229 - val_accuracy: 0.8822
# Epoch 19/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2756 - accuracy: 0.8996 - val_loss: 0.3586 - val_accuracy: 0.8624
# Epoch 20/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2708 - accuracy: 0.9024 - val_loss: 0.3171 - val_accuracy: 0.8820
# Epoch 21/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2659 - accuracy: 0.9038 - val_loss: 0.3156 - val_accuracy: 0.8868
# Epoch 22/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2606 - accuracy: 0.9055 - val_loss: 0.3126 - val_accuracy: 0.8872
# Epoch 23/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2569 - accuracy: 0.9077 - val_loss: 0.3387 - val_accuracy: 0.8752
# Epoch 24/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2514 - accuracy: 0.9101 - val_loss: 0.3107 - val_accuracy: 0.8878
# Epoch 25/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2470 - accuracy: 0.9113 - val_loss: 0.3122 - val_accuracy: 0.8872
# Epoch 26/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2435 - accuracy: 0.9124 - val_loss: 0.3101 - val_accuracy: 0.8850
# Epoch 27/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2385 - accuracy: 0.9149 - val_loss: 0.3135 - val_accuracy: 0.8872
# Epoch 28/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2357 - accuracy: 0.9153 - val_loss: 0.3127 - val_accuracy: 0.8886
# Epoch 29/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2315 - accuracy: 0.9169 - val_loss: 0.3163 - val_accuracy: 0.8860
# Epoch 30/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2280 - accuracy: 0.9181 - val_loss: 0.3072 - val_accuracy: 0.8890

# %%
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2231 - accuracy: 0.9208 - val_loss: 0.3328 - val_accuracy: 0.8818
# Epoch 2/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2208 - accuracy: 0.9208 - val_loss: 0.3170 - val_accuracy: 0.8854
# Epoch 3/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2152 - accuracy: 0.9231 - val_loss: 0.3126 - val_accuracy: 0.8874
# Epoch 4/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2136 - accuracy: 0.9250 - val_loss: 0.3023 - val_accuracy: 0.8934
# Epoch 5/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2095 - accuracy: 0.9259 - val_loss: 0.3027 - val_accuracy: 0.8896
# Epoch 6/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2061 - accuracy: 0.9271 - val_loss: 0.3183 - val_accuracy: 0.8898
# Epoch 7/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2031 - accuracy: 0.9271 - val_loss: 0.3185 - val_accuracy: 0.8904
# Epoch 8/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1995 - accuracy: 0.9292 - val_loss: 0.3062 - val_accuracy: 0.8906
# Epoch 9/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1972 - accuracy: 0.9303 - val_loss: 0.2990 - val_accuracy: 0.8926
# Epoch 10/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1923 - accuracy: 0.9313 - val_loss: 0.3153 - val_accuracy: 0.8896
# Epoch 11/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1904 - accuracy: 0.9326 - val_loss: 0.3123 - val_accuracy: 0.8898
# Epoch 12/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1875 - accuracy: 0.9325 - val_loss: 0.3060 - val_accuracy: 0.8906
# Epoch 13/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1842 - accuracy: 0.9343 - val_loss: 0.3008 - val_accuracy: 0.8928
# Epoch 14/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1813 - accuracy: 0.9359 - val_loss: 0.3186 - val_accuracy: 0.8880
# Epoch 15/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1779 - accuracy: 0.9373 - val_loss: 0.3142 - val_accuracy: 0.8924
# Epoch 16/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1748 - accuracy: 0.9382 - val_loss: 0.3234 - val_accuracy: 0.8898
# Epoch 17/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1731 - accuracy: 0.9387 - val_loss: 0.3099 - val_accuracy: 0.8900
# Epoch 18/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1691 - accuracy: 0.9395 - val_loss: 0.3078 - val_accuracy: 0.8900
# Epoch 19/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1674 - accuracy: 0.9402 - val_loss: 0.3438 - val_accuracy: 0.8754
# Epoch 20/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1640 - accuracy: 0.9433 - val_loss: 0.3191 - val_accuracy: 0.8896
# Epoch 21/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1617 - accuracy: 0.9422 - val_loss: 0.3100 - val_accuracy: 0.8914
# Epoch 22/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1587 - accuracy: 0.9441 - val_loss: 0.3234 - val_accuracy: 0.8882
# Epoch 23/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1566 - accuracy: 0.9447 - val_loss: 0.3413 - val_accuracy: 0.8834
# Epoch 24/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1534 - accuracy: 0.9461 - val_loss: 0.3098 - val_accuracy: 0.8940
# Epoch 25/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1511 - accuracy: 0.9465 - val_loss: 0.3262 - val_accuracy: 0.8888
# Epoch 26/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1491 - accuracy: 0.9472 - val_loss: 0.3272 - val_accuracy: 0.8932
# Epoch 27/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1455 - accuracy: 0.9489 - val_loss: 0.3238 - val_accuracy: 0.8908
# Epoch 28/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1440 - accuracy: 0.9495 - val_loss: 0.3267 - val_accuracy: 0.8946
# Epoch 29/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1419 - accuracy: 0.9496 - val_loss: 0.3324 - val_accuracy: 0.8908
# Epoch 30/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1393 - accuracy: 0.9511 - val_loss: 0.3233 - val_accuracy: 0.8916
# Epoch 31/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1362 - accuracy: 0.9525 - val_loss: 0.3347 - val_accuracy: 0.8932
# Epoch 32/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1354 - accuracy: 0.9529 - val_loss: 0.3225 - val_accuracy: 0.8930
# Epoch 33/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1319 - accuracy: 0.9546 - val_loss: 0.3423 - val_accuracy: 0.8880
# Epoch 34/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1298 - accuracy: 0.9545 - val_loss: 0.3292 - val_accuracy: 0.8940
# Epoch 35/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1271 - accuracy: 0.9565 - val_loss: 0.3244 - val_accuracy: 0.8934
# Epoch 36/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1246 - accuracy: 0.9567 - val_loss: 0.3343 - val_accuracy: 0.8882
# Epoch 37/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1231 - accuracy: 0.9569 - val_loss: 0.3437 - val_accuracy: 0.8896
# Epoch 38/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1222 - accuracy: 0.9566 - val_loss: 0.3360 - val_accuracy: 0.8890
# Epoch 39/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1193 - accuracy: 0.9593 - val_loss: 0.3334 - val_accuracy: 0.8968
# Epoch 40/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1171 - accuracy: 0.9593 - val_loss: 0.3281 - val_accuracy: 0.8930
# Epoch 41/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1159 - accuracy: 0.9597 - val_loss: 0.3366 - val_accuracy: 0.8964
# Epoch 42/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1137 - accuracy: 0.9604 - val_loss: 0.3414 - val_accuracy: 0.8900
# Epoch 43/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1118 - accuracy: 0.9609 - val_loss: 0.3803 - val_accuracy: 0.8856
# Epoch 44/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1101 - accuracy: 0.9617 - val_loss: 0.3424 - val_accuracy: 0.8956
# Epoch 45/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.1101 - accuracy: 0.9620 - val_loss: 0.3314 - val_accuracy: 0.8956
# Epoch 46/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1061 - accuracy: 0.9638 - val_loss: 0.3562 - val_accuracy: 0.8908
# Epoch 47/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.1038 - accuracy: 0.9649 - val_loss: 0.3484 - val_accuracy: 0.8896
# Epoch 48/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1034 - accuracy: 0.9644 - val_loss: 0.3646 - val_accuracy: 0.8878
# Epoch 49/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.1011 - accuracy: 0.9651 - val_loss: 0.3554 - val_accuracy: 0.8944
# Epoch 50/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0987 - accuracy: 0.9659 - val_loss: 0.3485 - val_accuracy: 0.8954
# Epoch 51/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0974 - accuracy: 0.9669 - val_loss: 0.3594 - val_accuracy: 0.8904
# Epoch 52/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0955 - accuracy: 0.9668 - val_loss: 0.3711 - val_accuracy: 0.8902
# Epoch 53/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0948 - accuracy: 0.9675 - val_loss: 0.3653 - val_accuracy: 0.8920
# Epoch 54/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0924 - accuracy: 0.9681 - val_loss: 0.3550 - val_accuracy: 0.8946
# Epoch 55/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0915 - accuracy: 0.9689 - val_loss: 0.4285 - val_accuracy: 0.8818
# Epoch 56/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0897 - accuracy: 0.9696 - val_loss: 0.3606 - val_accuracy: 0.8946
# Epoch 57/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0882 - accuracy: 0.9708 - val_loss: 0.3767 - val_accuracy: 0.8918
# Epoch 58/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0872 - accuracy: 0.9698 - val_loss: 0.3873 - val_accuracy: 0.8854
# Epoch 59/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0862 - accuracy: 0.9705 - val_loss: 0.3590 - val_accuracy: 0.8920
# Epoch 60/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0839 - accuracy: 0.9714 - val_loss: 0.3638 - val_accuracy: 0.8924
# Epoch 61/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0826 - accuracy: 0.9727 - val_loss: 0.3749 - val_accuracy: 0.8972
# Epoch 62/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0806 - accuracy: 0.9730 - val_loss: 0.3753 - val_accuracy: 0.8892
# Epoch 63/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0803 - accuracy: 0.9730 - val_loss: 0.3929 - val_accuracy: 0.8864
# Epoch 64/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0793 - accuracy: 0.9737 - val_loss: 0.3764 - val_accuracy: 0.8934
# Epoch 65/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0777 - accuracy: 0.9738 - val_loss: 0.3857 - val_accuracy: 0.8874
# Epoch 66/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0743 - accuracy: 0.9751 - val_loss: 0.4082 - val_accuracy: 0.8890
# Epoch 67/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0755 - accuracy: 0.9747 - val_loss: 0.3966 - val_accuracy: 0.8868
# Epoch 68/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0742 - accuracy: 0.9757 - val_loss: 0.3885 - val_accuracy: 0.8956
# Epoch 69/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0722 - accuracy: 0.9762 - val_loss: 0.3829 - val_accuracy: 0.8944
# Epoch 70/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0698 - accuracy: 0.9771 - val_loss: 0.3956 - val_accuracy: 0.8942
# Epoch 71/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0696 - accuracy: 0.9767 - val_loss: 0.3907 - val_accuracy: 0.8928
# Epoch 72/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0683 - accuracy: 0.9769 - val_loss: 0.4348 - val_accuracy: 0.8892
# Epoch 73/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0657 - accuracy: 0.9779 - val_loss: 0.4188 - val_accuracy: 0.8888
# Epoch 74/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0674 - accuracy: 0.9773 - val_loss: 0.4009 - val_accuracy: 0.8918
# Epoch 75/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0644 - accuracy: 0.9791 - val_loss: 0.3991 - val_accuracy: 0.8918
# Epoch 76/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0629 - accuracy: 0.9792 - val_loss: 0.4136 - val_accuracy: 0.8890
# Epoch 77/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0619 - accuracy: 0.9799 - val_loss: 0.4021 - val_accuracy: 0.8936
# Epoch 78/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0615 - accuracy: 0.9798 - val_loss: 0.4161 - val_accuracy: 0.8902
# Epoch 79/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0605 - accuracy: 0.9800 - val_loss: 0.4071 - val_accuracy: 0.8942
# Epoch 80/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0601 - accuracy: 0.9799 - val_loss: 0.4229 - val_accuracy: 0.8918
# Epoch 81/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0577 - accuracy: 0.9809 - val_loss: 0.4193 - val_accuracy: 0.8930
# Epoch 82/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0561 - accuracy: 0.9815 - val_loss: 0.4368 - val_accuracy: 0.8864
# Epoch 83/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0570 - accuracy: 0.9811 - val_loss: 0.4111 - val_accuracy: 0.8940
# Epoch 84/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0550 - accuracy: 0.9823 - val_loss: 0.4354 - val_accuracy: 0.8888
# Epoch 85/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0532 - accuracy: 0.9828 - val_loss: 0.4172 - val_accuracy: 0.8948
# Epoch 86/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0532 - accuracy: 0.9827 - val_loss: 0.4361 - val_accuracy: 0.8940
# Epoch 87/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0526 - accuracy: 0.9825 - val_loss: 0.4459 - val_accuracy: 0.8926
# Epoch 88/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0512 - accuracy: 0.9832 - val_loss: 0.4487 - val_accuracy: 0.8900
# Epoch 89/100
#  900/1719 [==============>...............] - ETA: 3s - loss: 0.0484 - accuracy: 0.9848
