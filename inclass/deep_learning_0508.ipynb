# %% [markdown]
# <a href="https://colab.research.google.com/github/syejin2004/deep-learning/blob/main/inclass/deep_learning_0508.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://drive.google.com/drive/folders/1au-YisCBRDR6IEzAGCXyrATHxl1Aw1f3

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tensorflow as tf
import os
import PIL
import shutil

base_dir = './OX_images/'
train_dir = os.path.join(base_dir, 'train')
vaildation_dir = os.path.join(base_dir, 'vaildation')
test_dir = os.path.join(base_dir, 'test')

train_o_dir = os.path.join(train_dir, 'O')
train_x_dir = os.path.join(train_dir, 'X')
print(train_o_dir, train_x_dir)

vaildation_o_dir = os.path.join(vaildation_dir, 'O')
vaildation_x_dir = os.path.join(vaildation_dir, 'X')
print(vaildation_o_dir, vaildation_x_dir)

test_o_dir = os.path.join(test_dir, 'O')
test_x_dir = os.path.join(test_dir, 'X')
print(test_o_dir, test_x_dir)
# Out:
# ./OX_images/train/O ./OX_images/train/X
# ./OX_images/vaildation/O ./OX_images/vaildation/X
# ./OX_images/test/O ./OX_images/test/X

# %%
train_o_fnames = os.listdir(train_o_dir)
train_x_fnames = os.listdir(train_x_dir)
print(train_o_fnames)
print(train_x_fnames)
# Out:
# ['20223618-O1.png', '20220371 6.png', '20232502._3.png', '20231563_o5.png', '20232882-o2.png', '20223618-O3.png', '20231576O8.png', '20223618-O18.png', '20231575_O_05.png', '20231559.o10.png', '20231559.o1.png', '20223618-O17.png', '20231567_O5.png', '55-3-o.png', '20221667-2.png', '2023156510.png', '20210829-O3.png', '20232505_o1.png', '20221667-3.png', '20220371 8.png', '20231559.o6.png', '202315658.png', '20223618-O8.png', '202315657.png', '202315655.png', '20232877-9.png', '1562_o1.png', '20210829-O6.png', '202315656.png', '20223618-O5.png', '20232877-5.png', '20232882-o6.png', '원1.png', '20223618-O14.png', '20232882-o9.png', '1562_o9.png', '1573_6.png', '20232882-o7.png', '20232877-7.png', '55-4-o.png', '20223618-O10.png', '20210829-O7.png', '1562_o5.png', '20232882-o8.png', '20232502_6.png', '20223618-O9.png', '20232505_o2.png', '1562_o2.png', '20231576O4.png', '202315654.png', '20232502._4.png', '202315652.png', '20231576O10.png', '20231567_O3.png', '20232882-o1.png', '20231568O5.png', '1562_o6.png', '20231559.o5.png', '20221667-1.png', '2880_0.png', '20231576O6.png', '20223618-O13.png', '20210829-O9.png', '20223618-O12.png', '20231563_o6.png', '20232505_o7.png', '20232505_o8.png', '20232505_o9.png', '20231563_o10.png', '202315653.png', '20231575_O_09.png', '20210829-O10.png', '55-8-o.png', '20223618-O19.png', '55-5-o.png', '20231575_O_07.png', '1573_5.png', '20231575_O_10.png', '20231559.o2.png', '20232877.png', '20210829-O2.png', '20231567_O7.png', '20231567_O4.png', '20223618-O16.png', '20231563_o4.png', '20223618-O11.png', '55-10-o.png', '20220371 10.png', '20231568O4.png', '원3.png', '20221667-9.png', '원2.png', '20223618-O15.png', '20231576O5.png', '20231559.o3.png', '20220371 2.png', '55-7-o.png', '20232882-o5.png', '1562_o10.png', '55-9-o.png', '20221667-10.png', '55-6-o.png', '20231563_o7.png', '20231567_O6.png', '20231576O1.png', '1562_o3.png', '20231575_O_03.png', '20210829-O4.png', '20232882-o3.png', '20232505_o3.png', '20231563_o1.png', '20231559.o8.png', '20231567_O8.png', '20232505_o6.png', '20231567_O9.png', '20221667-7.png', '20231576O7.png', '20231559.o4.png', '20231568O1.png', '20232882-o10.png', '1573_3.png', '20231567_O10.png', '1573_7.png', '20221667-6.png', '20231576O2.png', '20231575_O_08.png', '20231567_O1.png', '20231575_O_01.png', '20231576O3.png', '20220371 9.png', '20232505_o5.png', '20221667-8.png', '20232502.png', '202315659.png', '20223618-O6.png', '20221667-5.png', '20220371 4.png', '20231576O9.png', '20231568O2.png', '55-2-o.png']
# ['20232877-1.png', '2023156512.png', '20220371 6.png', '20231559.x5.png', '20231575_X_09.png', '20231566_x5.png', '20231566_x.png', '1573_x_6.png', '20231563_x4.png', '20231563_x2.png', '20231576X4.png', '20231563_x8.png', '20231563_x5.png', '20221667X-6.png', '20231559.x8.png', '20232877-4.png', '20231568X5.png', '20223618-X7.png', '20231575_X_07.png', '20223618-X14.png', '20223618-X4.png', '20232505_x1.png', '20210829-X1.png', '20231566_x7.png', '20231576X3(1).png', '20231563_x6.png', '1562_x9.png', '20231567_X4.png', '20220371 8.png', '20232882-x3.png', '20221667X-7.png', '20231567_X5.png', '20231567_X10.png', '1573_x_3.png', '20231575_X_01.png', '20210829-X6.png', '20231566_x4.png', '20210829-X4.png', '20223618-X13.png', '20231567_X6.png', '20231575_X_10.png', '20221667X--8.png', '20231576X6(1).png', '20210829-X3.png', '20232882-x7.png', '1562_x6.png', '20231559.x6.png', '20231563_x1.png', '20231576X10.png', '20220371 7.png', '20232505_x4.png', '20231576X9.png', '20232882-x8.png', '1562_x5.png', '20231559.x1.png', '20231563_x7.png', '1573_x_8.png', '20231567_X7.png', '20232877-10.png', '20220371 5.png', '20231559.x9.png', '20231559.x3.png', '20223618-X6.png', '20223618-X18.png', '20232505_x2.png', '20231568X1.png', '20221667X-1.png', '20231576X10(1).png', '20231576X8(1).png', '20232505_x3.png', '20210829-X7.png', '20231576X5(1).png', '2023156513.png', '20221667X-4.png', '20220371 3.png', '1562_x4.png', '20231559.x10.png', '20210829-X8.png', '20223618-X5.png', '20231575_X_06.png', '20231568X4.png', '20231576X9(1).png', '20221667X-3.png', '20232505_x5.png', '20232882-x2.png', '20232505_x7.png', '20231559.x7.png', '20210829-X2.png', '20223618-X1.png', '1562_x10.png', '20231566_x1.png', '2023156511.png', '20231559.x4.png', '20231563_x3.png', '20221667X-5.png', '1573_x_7.png', '20231576X1(1).png', '20232882-x10.png', '20231575_X_02.png', '20231576X3.png', '20231576X6.png', '20231567_X2.png', '20223618-X17.png', '20223618-X11.png', '20232882-x1.png', '20220371 2..png', '1573_x_5.png', '20223618-X3.png', '20231568X3.png', '20231568X2.png', '20231567_X1.png', '1573_x_4.png', '20231576X1.png', '20231576X8.png', '20210829-X5.png', '20231576X4(1).png', '20232882-x9.png', '20231566_x6.png', '20231566_x3.png', '20232505_x6.png', '20223618-X15.png', '1562_x8.png', '20231567_X3.png', '20231576X5.png', '20231563_x10.png', '1573_x_9.png', '20231563_x9.png', '1562_x7.png', '20231575_X_08.png', '20232502_5.png', '20220371 1.png', '1573_x_10.png', '20223618-X16.png', '20231566_x2.png', '1562_x3.png', '20223618-X8.png', '20232877-6.png', '20231575_X_05.png', '20220371 4.png', '20232502_2.png']

# %%
print('Total training o images :', len(os.listdir(train_o_dir)))
print('Total training x images :', len(os.listdir(train_x_dir)))

print('Total vaildation o images :', len(os.listdir(vaildation_o_dir)))
print('Total vaildation x images :', len(os.listdir(vaildation_x_dir)))

print('Total test o images :', len(os.listdir(test_o_dir)))
print('Total test x images :', len(os.listdir(test_x_dir)))
# Out:
# Total training o images : 140
# Total training x images : 140
# Total vaildation o images : 20
# Total vaildation x images : 20
# Total test o images : 20
# Total test x images : 20

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_o_pix = [os.path.join(train_o_dir, fname) for fname in train_o_fnames[pic_index-8:pic_index]]
next_x_pix = [os.path.join(train_x_dir, fname) for fname in train_x_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_o_pix+next_x_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('OFF')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import os

folder_path = './OX_images/vaildation/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")

folder_path = './OX_images/train/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")

folder_path = './OX_images/test/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")
# Out:
# Folder deleted successfully.
# Folder not found.
# Folder not found.

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=25,
                                   width_shift_range=0.05,
                                   height_shift_range=0.05,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

vaildation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=16,
                                                    color_mode='grayscale',
                                                    class_mode='binary',
                                                    target_size=(150, 150))

vaildation_genertor = vaildation_datagen.flow_from_directory(vaildation_dir,
                                                    batch_size=4,
                                                    color_mode='grayscale',
                                                    class_mode='binary',
                                                    target_size=(150, 150))

test_generator = test_datagen.flow_from_directory(test_dir,
                                                    batch_size=4,
                                                    color_mode='grayscale',
                                                    class_mode='binary',
                                                    target_size=(150, 150))
# Out:
# Found 280 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'O': 0, 'X': 1}

# %%
sample_img = mpimg.imread(next_o_pix[0])
plt.imshow(sample_img)
plt.show()

# %%
max_iter = 4
cnt = 1
sample_img2 = sample_img[np.newaxis, ...]

plt.figure(figsize=(10, 10))
for img in train_datagen.flow(sample_img2):
  plt.subplot(1, max_iter, cnt)
  plt.imshow(image.array_to_img(img[0]))
  if cnt == max_iter:
    break
  cnt += 1

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 148, 148, 16)      160
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 16)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9248)              0
#
#  dense_2 (Dense)             (None, 512)               4735488
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 4750049 (18.12 MB)
# Trainable params: 4750049 (18.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
                              validation_data=vaildation_genertor, # validatino_generator안에도 검증용 X,y데이터들이 다 있으니 generator로 주면 됨
                              steps_per_epoch=4, # 한 번의 에포크(epoch)에서 훈련에 사용할 배치(batch)의 개수 지정; generator를 4번 부르겠다
                              epochs=100, # 데이터셋을 한 번 훈련하는 과정; epoch은 100 이상은 줘야한다
                              validation_steps=4, # 한 번의 에포크가 끝날 때, 검증에 사용되는 배치(batch)의 개수를 지정;
                                                  # validation_generator를 4번 불러서 나온 이미지들로 작업을 해라
                              verbose=2)
# Out:
# <ipython-input-36-52123f1b7720>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
# Epoch 1/100
# 4/4 - 4s - loss: 1.0871 - accuracy: 0.5000 - val_loss: 0.7181 - val_accuracy: 0.3750 - 4s/epoch - 1s/step
# Epoch 2/100
# 4/4 - 2s - loss: 0.6971 - accuracy: 0.4844 - val_loss: 0.6762 - val_accuracy: 0.5000 - 2s/epoch - 381ms/step
# Epoch 3/100
# 4/4 - 2s - loss: 0.6806 - accuracy: 0.5781 - val_loss: 0.7169 - val_accuracy: 0.3750 - 2s/epoch - 402ms/step
# Epoch 4/100
# 4/4 - 2s - loss: 0.7516 - accuracy: 0.4219 - val_loss: 0.6545 - val_accuracy: 0.6875 - 2s/epoch - 384ms/step
# Epoch 5/100
# 4/4 - 2s - loss: 0.6530 - accuracy: 0.7188 - val_loss: 0.6607 - val_accuracy: 0.5000 - 2s/epoch - 384ms/step
# Epoch 6/100
# 4/4 - 3s - loss: 0.6140 - accuracy: 0.5781 - val_loss: 0.4738 - val_accuracy: 0.6250 - 3s/epoch - 660ms/step
# Epoch 7/100
# 4/4 - 1s - loss: 0.5948 - accuracy: 0.5938 - val_loss: 0.3487 - val_accuracy: 0.9375 - 1s/epoch - 374ms/step
# Epoch 8/100
# 4/4 - 1s - loss: 0.5564 - accuracy: 0.7500 - val_loss: 0.4856 - val_accuracy: 0.6875 - 1s/epoch - 357ms/step
# Epoch 9/100
# 4/4 - 2s - loss: 0.4411 - accuracy: 0.7500 - val_loss: 0.3289 - val_accuracy: 0.8750 - 2s/epoch - 378ms/step
# Epoch 10/100
# 4/4 - 2s - loss: 0.3258 - accuracy: 0.8594 - val_loss: 0.2702 - val_accuracy: 0.9375 - 2s/epoch - 393ms/step
# Epoch 11/100
# 4/4 - 2s - loss: 0.4046 - accuracy: 0.8281 - val_loss: 0.2942 - val_accuracy: 0.8750 - 2s/epoch - 526ms/step
# Epoch 12/100
# 4/4 - 2s - loss: 0.3601 - accuracy: 0.8929 - val_loss: 0.2779 - val_accuracy: 0.8750 - 2s/epoch - 561ms/step
# Epoch 13/100
# 4/4 - 1s - loss: 0.3516 - accuracy: 0.8571 - val_loss: 0.3826 - val_accuracy: 0.8125 - 1s/epoch - 330ms/step
# Epoch 14/100
# 4/4 - 1s - loss: 0.1722 - accuracy: 0.9219 - val_loss: 0.4810 - val_accuracy: 0.6875 - 1s/epoch - 361ms/step
# Epoch 15/100
# 4/4 - 1s - loss: 0.1949 - accuracy: 0.9062 - val_loss: 0.0777 - val_accuracy: 1.0000 - 1s/epoch - 361ms/step
# Epoch 16/100
# 4/4 - 1s - loss: 0.2678 - accuracy: 0.8906 - val_loss: 0.1887 - val_accuracy: 0.8750 - 1s/epoch - 371ms/step
# Epoch 17/100
# 4/4 - 2s - loss: 0.4796 - accuracy: 0.8281 - val_loss: 0.1856 - val_accuracy: 0.9375 - 2s/epoch - 494ms/step
# Epoch 18/100
# 4/4 - 3s - loss: 0.2457 - accuracy: 0.9464 - val_loss: 0.1729 - val_accuracy: 0.9375 - 3s/epoch - 644ms/step
# Epoch 19/100
# 4/4 - 2s - loss: 0.9811 - accuracy: 0.7679 - val_loss: 0.1763 - val_accuracy: 0.9375 - 2s/epoch - 396ms/step
# Epoch 20/100
# 4/4 - 2s - loss: 0.3423 - accuracy: 0.8906 - val_loss: 0.2311 - val_accuracy: 0.9375 - 2s/epoch - 484ms/step
# Epoch 21/100
# 4/4 - 2s - loss: 0.3302 - accuracy: 0.8594 - val_loss: 0.2501 - val_accuracy: 0.8750 - 2s/epoch - 392ms/step
# Epoch 22/100
# 4/4 - 2s - loss: 0.2005 - accuracy: 0.9107 - val_loss: 0.2645 - val_accuracy: 0.8125 - 2s/epoch - 609ms/step
# Epoch 23/100
# 4/4 - 3s - loss: 0.2141 - accuracy: 0.9219 - val_loss: 0.2126 - val_accuracy: 0.9375 - 3s/epoch - 670ms/step
# Epoch 24/100
# 4/4 - 2s - loss: 0.2219 - accuracy: 0.9219 - val_loss: 0.0783 - val_accuracy: 0.9375 - 2s/epoch - 384ms/step
# Epoch 25/100
# 4/4 - 1s - loss: 0.2180 - accuracy: 0.9219 - val_loss: 0.2471 - val_accuracy: 0.8750 - 1s/epoch - 373ms/step
# Epoch 26/100
# 4/4 - 2s - loss: 0.2569 - accuracy: 0.8906 - val_loss: 0.2034 - val_accuracy: 0.9375 - 2s/epoch - 377ms/step
# Epoch 27/100
# 4/4 - 1s - loss: 0.2591 - accuracy: 0.9219 - val_loss: 0.1600 - val_accuracy: 0.8750 - 1s/epoch - 368ms/step
# Epoch 28/100
# 4/4 - 2s - loss: 0.1073 - accuracy: 0.9688 - val_loss: 0.1698 - val_accuracy: 0.9375 - 2s/epoch - 423ms/step
# Epoch 29/100
# 4/4 - 4s - loss: 0.1863 - accuracy: 0.9531 - val_loss: 0.0633 - val_accuracy: 0.9375 - 4s/epoch - 942ms/step
# Epoch 30/100
# 4/4 - 2s - loss: 0.1736 - accuracy: 0.9531 - val_loss: 0.3490 - val_accuracy: 0.8750 - 2s/epoch - 388ms/step
# Epoch 31/100
# 4/4 - 2s - loss: 0.2036 - accuracy: 0.9375 - val_loss: 0.2361 - val_accuracy: 0.9375 - 2s/epoch - 375ms/step
# Epoch 32/100
# 4/4 - 1s - loss: 0.1898 - accuracy: 0.9531 - val_loss: 0.1341 - val_accuracy: 0.9375 - 1s/epoch - 367ms/step
# Epoch 33/100
# 4/4 - 2s - loss: 0.2510 - accuracy: 0.9219 - val_loss: 0.0768 - val_accuracy: 0.9375 - 2s/epoch - 518ms/step
# Epoch 34/100
# 4/4 - 2s - loss: 0.2150 - accuracy: 0.9219 - val_loss: 0.1216 - val_accuracy: 0.9375 - 2s/epoch - 603ms/step
# Epoch 35/100
# 4/4 - 2s - loss: 0.1928 - accuracy: 0.9375 - val_loss: 0.3519 - val_accuracy: 0.8750 - 2s/epoch - 377ms/step
# Epoch 36/100
# 4/4 - 1s - loss: 0.2159 - accuracy: 0.9375 - val_loss: 0.2512 - val_accuracy: 0.9375 - 1s/epoch - 371ms/step
# Epoch 37/100
# 4/4 - 1s - loss: 0.0941 - accuracy: 0.9844 - val_loss: 0.0610 - val_accuracy: 0.9375 - 1s/epoch - 348ms/step
# Epoch 38/100
# 4/4 - 1s - loss: 0.1168 - accuracy: 0.9219 - val_loss: 0.2282 - val_accuracy: 0.8125 - 1s/epoch - 369ms/step
# Epoch 39/100
# 4/4 - 1s - loss: 0.0993 - accuracy: 0.9464 - val_loss: 0.0057 - val_accuracy: 1.0000 - 1s/epoch - 350ms/step
# Epoch 40/100
# 4/4 - 2s - loss: 0.1941 - accuracy: 0.9107 - val_loss: 0.2422 - val_accuracy: 0.9375 - 2s/epoch - 593ms/step
# Epoch 41/100
# 4/4 - 2s - loss: 0.1819 - accuracy: 0.9464 - val_loss: 0.2968 - val_accuracy: 0.8750 - 2s/epoch - 412ms/step
# Epoch 42/100
# 4/4 - 2s - loss: 0.1751 - accuracy: 0.9219 - val_loss: 0.0792 - val_accuracy: 0.9375 - 2s/epoch - 379ms/step
# Epoch 43/100
# 4/4 - 2s - loss: 0.1961 - accuracy: 0.9219 - val_loss: 0.0197 - val_accuracy: 1.0000 - 2s/epoch - 380ms/step
# Epoch 44/100
# 4/4 - 1s - loss: 0.1859 - accuracy: 0.9643 - val_loss: 0.2197 - val_accuracy: 0.9375 - 1s/epoch - 339ms/step
# Epoch 45/100
# 4/4 - 2s - loss: 0.1208 - accuracy: 0.9531 - val_loss: 0.3125 - val_accuracy: 0.9375 - 2s/epoch - 382ms/step
# Epoch 46/100
# 4/4 - 3s - loss: 0.1440 - accuracy: 0.9375 - val_loss: 0.1672 - val_accuracy: 0.9375 - 3s/epoch - 662ms/step
# Epoch 47/100
# 4/4 - 1s - loss: 0.1191 - accuracy: 0.9375 - val_loss: 0.0139 - val_accuracy: 1.0000 - 1s/epoch - 365ms/step
# Epoch 48/100
# 4/4 - 1s - loss: 0.1744 - accuracy: 0.9219 - val_loss: 0.0246 - val_accuracy: 1.0000 - 1s/epoch - 362ms/step
# Epoch 49/100
# 4/4 - 2s - loss: 0.2326 - accuracy: 0.8906 - val_loss: 0.0496 - val_accuracy: 1.0000 - 2s/epoch - 388ms/step
# Epoch 50/100
# 4/4 - 1s - loss: 0.0665 - accuracy: 0.9688 - val_loss: 0.2433 - val_accuracy: 0.9375 - 1s/epoch - 368ms/step
# Epoch 51/100
# 4/4 - 3s - loss: 0.1955 - accuracy: 0.9531 - val_loss: 0.0192 - val_accuracy: 1.0000 - 3s/epoch - 641ms/step
# Epoch 52/100
# 4/4 - 2s - loss: 0.0604 - accuracy: 0.9688 - val_loss: 0.0213 - val_accuracy: 1.0000 - 2s/epoch - 386ms/step
# Epoch 53/100
# 4/4 - 1s - loss: 0.0918 - accuracy: 0.9531 - val_loss: 0.0048 - val_accuracy: 1.0000 - 1s/epoch - 361ms/step
# Epoch 54/100
# 4/4 - 1s - loss: 0.1736 - accuracy: 0.9375 - val_loss: 0.0212 - val_accuracy: 1.0000 - 1s/epoch - 372ms/step
# Epoch 55/100
# 4/4 - 2s - loss: 0.1186 - accuracy: 0.9375 - val_loss: 0.0833 - val_accuracy: 0.9375 - 2s/epoch - 406ms/step
# Epoch 56/100
# 4/4 - 2s - loss: 0.0952 - accuracy: 0.9844 - val_loss: 0.0115 - val_accuracy: 1.0000 - 2s/epoch - 596ms/step
# Epoch 57/100
# 4/4 - 2s - loss: 0.0577 - accuracy: 0.9844 - val_loss: 0.0045 - val_accuracy: 1.0000 - 2s/epoch - 442ms/step
# Epoch 58/100
# 4/4 - 2s - loss: 0.1670 - accuracy: 0.9531 - val_loss: 0.0080 - val_accuracy: 1.0000 - 2s/epoch - 386ms/step
# Epoch 59/100
# 4/4 - 1s - loss: 0.1270 - accuracy: 0.9219 - val_loss: 4.4496e-04 - val_accuracy: 1.0000 - 1s/epoch - 373ms/step
# Epoch 60/100
# 4/4 - 2s - loss: 0.1368 - accuracy: 0.9375 - val_loss: 0.2191 - val_accuracy: 0.9375 - 2s/epoch - 389ms/step
# Epoch 61/100
# 4/4 - 2s - loss: 0.0503 - accuracy: 0.9844 - val_loss: 0.2723 - val_accuracy: 0.9375 - 2s/epoch - 468ms/step
# Epoch 62/100
# 4/4 - 2s - loss: 0.1008 - accuracy: 0.9531 - val_loss: 0.0065 - val_accuracy: 1.0000 - 2s/epoch - 602ms/step
# Epoch 63/100
# 4/4 - 2s - loss: 0.0717 - accuracy: 0.9844 - val_loss: 0.2843 - val_accuracy: 0.9375 - 2s/epoch - 452ms/step
# Epoch 64/100
# 4/4 - 2s - loss: 0.1317 - accuracy: 0.9531 - val_loss: 0.2782 - val_accuracy: 0.9375 - 2s/epoch - 380ms/step
# Epoch 65/100
# 4/4 - 2s - loss: 0.0725 - accuracy: 0.9844 - val_loss: 0.0018 - val_accuracy: 1.0000 - 2s/epoch - 395ms/step
# Epoch 66/100
# 4/4 - 2s - loss: 0.1429 - accuracy: 0.9531 - val_loss: 0.0058 - val_accuracy: 1.0000 - 2s/epoch - 389ms/step
# Epoch 67/100
# 4/4 - 1s - loss: 0.1050 - accuracy: 0.9375 - val_loss: 0.1260 - val_accuracy: 0.9375 - 1s/epoch - 368ms/step
# Epoch 68/100
# 4/4 - 2s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 2s/epoch - 551ms/step
# Epoch 69/100
# 4/4 - 2s - loss: 0.0629 - accuracy: 0.9821 - val_loss: 0.2496 - val_accuracy: 0.9375 - 2s/epoch - 573ms/step
# Epoch 70/100
# 4/4 - 1s - loss: 0.2091 - accuracy: 0.9286 - val_loss: 0.0096 - val_accuracy: 1.0000 - 1s/epoch - 343ms/step
# Epoch 71/100
# 4/4 - 1s - loss: 0.0872 - accuracy: 0.9531 - val_loss: 0.0311 - val_accuracy: 1.0000 - 1s/epoch - 357ms/step
# Epoch 72/100
# 4/4 - 1s - loss: 0.1473 - accuracy: 0.9219 - val_loss: 0.0236 - val_accuracy: 1.0000 - 1s/epoch - 365ms/step
# Epoch 73/100
# 4/4 - 2s - loss: 0.1637 - accuracy: 0.9375 - val_loss: 0.0077 - val_accuracy: 1.0000 - 2s/epoch - 401ms/step
# Epoch 74/100
# 4/4 - 2s - loss: 0.0945 - accuracy: 0.9688 - val_loss: 0.0183 - val_accuracy: 1.0000 - 2s/epoch - 386ms/step
# Epoch 75/100
# 4/4 - 2s - loss: 0.0625 - accuracy: 0.9688 - val_loss: 0.0712 - val_accuracy: 0.9375 - 2s/epoch - 399ms/step
# Epoch 76/100
# 4/4 - 2s - loss: 0.1695 - accuracy: 0.9286 - val_loss: 0.1621 - val_accuracy: 0.9375 - 2s/epoch - 554ms/step
# Epoch 77/100
# 4/4 - 2s - loss: 0.0721 - accuracy: 0.9844 - val_loss: 0.2026 - val_accuracy: 0.9375 - 2s/epoch - 418ms/step
# Epoch 78/100
# 4/4 - 2s - loss: 0.1000 - accuracy: 0.9688 - val_loss: 0.0771 - val_accuracy: 0.9375 - 2s/epoch - 383ms/step
# Epoch 79/100
# 4/4 - 2s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9375 - 2s/epoch - 382ms/step
# Epoch 80/100
# 4/4 - 2s - loss: 0.1897 - accuracy: 0.9375 - val_loss: 0.1137 - val_accuracy: 0.9375 - 2s/epoch - 385ms/step
# Epoch 81/100
# 4/4 - 2s - loss: 0.1212 - accuracy: 0.9531 - val_loss: 0.0496 - val_accuracy: 0.9375 - 2s/epoch - 392ms/step
# Epoch 82/100
# 4/4 - 3s - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9375 - 3s/epoch - 658ms/step
# Epoch 83/100
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.9844 - val_loss: 0.0040 - val_accuracy: 1.0000 - 2s/epoch - 531ms/step
# Epoch 84/100
# 4/4 - 2s - loss: 0.0581 - accuracy: 0.9688 - val_loss: 0.0391 - val_accuracy: 1.0000 - 2s/epoch - 390ms/step
# Epoch 85/100
# 4/4 - 1s - loss: 0.0558 - accuracy: 0.9844 - val_loss: 0.0010 - val_accuracy: 1.0000 - 1s/epoch - 358ms/step
# Epoch 86/100
# 4/4 - 2s - loss: 0.1059 - accuracy: 0.9688 - val_loss: 0.0038 - val_accuracy: 1.0000 - 2s/epoch - 378ms/step
# Epoch 87/100
# 4/4 - 1s - loss: 0.0777 - accuracy: 0.9844 - val_loss: 0.0155 - val_accuracy: 1.0000 - 1s/epoch - 375ms/step
# Epoch 88/100
# 4/4 - 2s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - 2s/epoch - 479ms/step
# Epoch 89/100
# 4/4 - 2s - loss: 0.0634 - accuracy: 0.9821 - val_loss: 5.9605e-05 - val_accuracy: 1.0000 - 2s/epoch - 578ms/step
# Epoch 90/100
# 4/4 - 2s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 9.4452e-04 - val_accuracy: 1.0000 - 2s/epoch - 388ms/step
# Epoch 91/100
# 4/4 - 2s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 2.0545e-05 - val_accuracy: 1.0000 - 2s/epoch - 394ms/step
# Epoch 92/100
# 4/4 - 1s - loss: 0.2080 - accuracy: 0.9531 - val_loss: 0.0090 - val_accuracy: 1.0000 - 1s/epoch - 369ms/step
# Epoch 93/100
# 4/4 - 2s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 7.5639e-04 - val_accuracy: 1.0000 - 2s/epoch - 395ms/step
# Epoch 94/100
# 4/4 - 2s - loss: 0.0286 - accuracy: 0.9844 - val_loss: 0.0012 - val_accuracy: 1.0000 - 2s/epoch - 379ms/step
# Epoch 95/100
# 4/4 - 3s - loss: 0.0266 - accuracy: 0.9844 - val_loss: 0.0168 - val_accuracy: 1.0000 - 3s/epoch - 627ms/step
# Epoch 96/100
# 4/4 - 2s - loss: 0.1689 - accuracy: 0.9464 - val_loss: 0.0043 - val_accuracy: 1.0000 - 2s/epoch - 511ms/step
# Epoch 97/100
# 4/4 - 1s - loss: 0.0797 - accuracy: 0.9643 - val_loss: 0.0605 - val_accuracy: 0.9375 - 1s/epoch - 337ms/step
# Epoch 98/100
# 4/4 - 2s - loss: 0.0470 - accuracy: 0.9844 - val_loss: 0.0446 - val_accuracy: 0.9375 - 2s/epoch - 386ms/step
# Epoch 99/100
# 4/4 - 2s - loss: 0.1819 - accuracy: 0.9531 - val_loss: 5.6750e-04 - val_accuracy: 1.0000 - 2s/epoch - 376ms/step
# Epoch 100/100
# 4/4 - 1s - loss: 0.0654 - accuracy: 0.9464 - val_loss: 4.7185e-04 - val_accuracy: 1.0000 - 1s/epoch - 333ms/step

# %%
model.evaluate(train_generator)
# Out:
# 18/18 [==============================] - 3s 157ms/step - loss: 0.0602 - accuracy: 0.9821
# [0.060173939913511276, 0.9821428656578064]

# %%
model.evaluate(vaildation_genertor)
# Out:
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0361 - accuracy: 0.9750
# [0.03607707470655441, 0.9750000238418579]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# 이제 테스트 이미지 분류
import numpy as np
from keras.preprocessing import image

# 테스트용 O 이미지 경로 설정
test_dir = './OX_images/test/'
test_o_dir = os.path.join(test_dir, 'O/')
test_o_filenames = os.listdir(test_o_dir)
test_o_filenames

# 테스트용 X 이미지 경로 설정
test_dir = './OX_images/test/'
test_x_dir = os.path.join(test_dir, 'X/')
test_x_filenames = os.listdir(test_x_dir)
test_x_filenames

# O,X를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_ox_filenames = {}
dic_ox_filenames['O'] = test_o_filenames
dic_ox_filenames['X'] = test_x_filenames

# O/X 분류 테스트
for ox, filenames in dic_ox_filenames.items():
    fig = plt.figure(figsize=(16,20))
    rows, cols = 1, 20
    for i, fn in enumerate(filenames):
        path = test_dir + ox + '/' + fn
        test_img = image.load_img(path, color_mode='grayscale', target_size=(150, 150), interpolation='bilinear')
        x = image.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = model.predict(images, batch_size=10)
        print(rows, cols, i+1)
        fig.add_subplot(rows, cols+1, i+1)
        if classes[0]==0:
            plt.title(fn + " is O")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
        else:
            plt.title(fn + " is X")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
    plt.show();
# Out:
# 1/1 [==============================] - 0s 179ms/step
# 1 20 1
# 1/1 [==============================] - 0s 39ms/step
# 1 20 2
# 1/1 [==============================] - 0s 124ms/step
# 1 20 3
# 1/1 [==============================] - 0s 94ms/step
# 1 20 4
# 1/1 [==============================] - 0s 70ms/step
# 1 20 5
# 1/1 [==============================] - 0s 45ms/step
# 1 20 6
# 1/1 [==============================] - 0s 51ms/step
# 1 20 7
# 1/1 [==============================] - 0s 41ms/step
# 1 20 8
# 1/1 [==============================] - 0s 45ms/step
# 1 20 9
# 1/1 [==============================] - 0s 26ms/step
# 1 20 10
# 1/1 [==============================] - 0s 32ms/step
# 1 20 11
# 1/1 [==============================] - 0s 31ms/step
# 1 20 12
# 1/1 [==============================] - 0s 28ms/step
# 1 20 13
# 1/1 [==============================] - 0s 37ms/step
# 1 20 14
# 1/1 [==============================] - 0s 32ms/step
# 1 20 15
# 1/1 [==============================] - 0s 32ms/step
# 1 20 16
# 1/1 [==============================] - 0s 30ms/step
# 1 20 17
# 1/1 [==============================] - 0s 29ms/step
# 1 20 18
# 1/1 [==============================] - 0s 28ms/step
# 1 20 19
# 1/1 [==============================] - 0s 26ms/step
# 1 20 20
# 1/1 [==============================] - 0s 30ms/step
# 1 20 1
# 1/1 [==============================] - 0s 28ms/step
# 1 20 2
# 1/1 [==============================] - 0s 32ms/step
# 1 20 3
# 1/1 [==============================] - 0s 28ms/step
# 1 20 4
# 1/1 [==============================] - 0s 33ms/step
# 1 20 5
# 1/1 [==============================] - 0s 31ms/step
# 1 20 6
# 1/1 [==============================] - 0s 28ms/step
# 1 20 7
# 1/1 [==============================] - 0s 30ms/step
# 1 20 8
# 1/1 [==============================] - 0s 32ms/step
# 1 20 9
# 1/1 [==============================] - 0s 30ms/step
# 1 20 10
# 1/1 [==============================] - 0s 31ms/step
# 1 20 11
# 1/1 [==============================] - 0s 27ms/step
# 1 20 12
# 1/1 [==============================] - 0s 29ms/step
# 1 20 13
# 1/1 [==============================] - 0s 32ms/step
# 1 20 14
# 1/1 [==============================] - 0s 31ms/step
# 1 20 15
# 1/1 [==============================] - 0s 31ms/step
# 1 20 16
# 1/1 [==============================] - 0s 30ms/step
# 1 20 17
# 1/1 [==============================] - 0s 31ms/step
# 1 20 18
# 1/1 [==============================] - 0s 29ms/step
# 1 20 19
# 1/1 [==============================] - 0s 36ms/step
# 1 20 20

# %%
model.save('ox_class_cnn.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
